# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import csv
import sys, os
sys.path.append('~/dsi/capstones/cap_3/')



# import sys, os
# os.path.dirname(sys.executable)

# /Users/cv/dsi/capstones/cap_3/notebooks

# http://cigarplug.ml/blog/mobile-device-specifications-from-gsmarena/

# %%
print(sys.path)
# Out:
# ['/Users/cv/dsi/capstones/cap_3/notebooks', '/Users/cv/anaconda3/lib/python37.zip', '/Users/cv/anaconda3/lib/python3.7', '/Users/cv/anaconda3/lib/python3.7/lib-dynload', '', '/Users/cv/anaconda3/lib/python3.7/site-packages', '/Users/cv/anaconda3/lib/python3.7/site-packages/aeosa', '/Users/cv/anaconda3/lib/python3.7/site-packages/python_louvain-0.13-py3.7.egg', '/Users/cv/anaconda3/lib/python3.7/site-packages/IPython/extensions', '/Users/cv/.ipython', '~/dsi/capstones/cap_3/']

# %%
# df_1 = pd.read_csv('../data/phone_dataset.csv')
df_2 = pd.read_csv('../data/gsm.csv')
# df_3 = pd.read_csv('../data/gsmarena_dataset.csv')
# Out:
# /Users/cv/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (75,76,77,79,80,81,82,83,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# df_1 = pd.read_csv('~/dsi/capstones/cap_3/data/phone_dataset.csv')

# %%
# df_1.head(10)

# %%
col_1 = sorted(df_1.columns)
# col_1

# with open('protagonist.csv', 'w', newline='') as file:
#     writer = csv.writer(file)
#     writer.writecols(row_list)

# %%
col_2 = sorted(df_2.columns)

# %%
len(df_2.columns)
df_2.shape
len(df_2.oem.unique())
# Out:
# 113

# %%
# sorted(df_3.columns)

# %%
df_2.head(10)
# Out:
#     oem                 model        network_technology  \
# 0  Acer     Chromebook Tab 10  No cellular connectivity
# 1  Acer         Iconia Talk S          GSM / HSPA / LTE
# 2  Acer        Liquid Z6 Plus          GSM / HSPA / LTE
# 3  Acer             Liquid Z6          GSM / HSPA / LTE
# 4  Acer  Iconia Tab 10 A3-A40  No cellular connectivity
# 5  Acer             Liquid X2          GSM / HSPA / LTE
# 6  Acer         Liquid Jade 2          GSM / HSPA / LTE
# 7  Acer      Liquid Zest Plus          GSM / HSPA / LTE
# 8  Acer           Liquid Zest          GSM / HSPA / LTE
# 9  Acer            Predator 8  No cellular connectivity
#
#                                     network_2g_bands network_gprs  \
# 0                                                NaN           No
# 1        GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2          Yes
# 2  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...          Yes
# 3  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...          Yes
# 4                                                NaN           No
# 5                        GSM 850 / 900 / 1800 / 1900          Yes
# 6        GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2          Yes
# 7  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...          Yes
# 8  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...          Yes
# 9                                                NaN           No
#
#   network_edge launch_announced                       launch_status  \
# 0           No      2018, March      Available. Released 2018, July
# 1          Yes     2016, August   Available. Released 2016, October
# 2          Yes     2016, August  Available. Released 2016, December
# 3          Yes     2016, August  Available. Released 2016, December
# 4           No      2016, April      Available. Released 2016, June
# 5          Yes      2015, April  Available. Released 2016, February
# 6          Yes   2016, February                           Available
# 7          Yes      2016, April      Available. Released 2016, July
# 8          Yes   2016, February     Available. Released 2016, April
# 9           No  2015, September  Available. Released 2015, November
#
#                                   body_dimensions         body_weight  ...  \
# 0  238.3 x 172.2 x 9.9 mm (9.38 x 6.78 x 0.39 in)   544.3 g (1.20 lb)  ...
# 1    191.7 x 101 x 9.4 mm (7.55 x 3.98 x 0.37 in)     260 g (9.17 oz)  ...
# 2   153.8 x 75.6 x 8.5 mm (6.06 x 2.98 x 0.33 in)     169 g (5.96 oz)  ...
# 3   145.5 x 72.5 x 8.5 mm (5.73 x 2.85 x 0.33 in)     126 g (4.44 oz)  ...
# 4     259 x 167 x 8.9 mm (10.20 x 6.57 x 0.35 in)                   -  ...
# 5   153.3 x 78.8 x 8.5 mm (6.04 x 3.10 x 0.33 in)     166 g (5.86 oz)  ...
# 6   156.6 x 75.9 x 8.4 mm (6.17 x 2.99 x 0.33 in)     150 g (5.29 oz)  ...
# 7        154 x 77 x 10 mm (6.06 x 3.03 x 0.39 in)                   -  ...
# 8   145.7 x 71.2 x 8.4 mm (5.74 x 2.80 x 0.33 in)     125 g (4.41 oz)  ...
# 9     217.9 x 127 x 8.6 mm (8.58 x 5.0 x 0.34 in)  353.8 g (12.49 oz)  ...
#
#   features_alarm features_languages main_camera_triple selfie_camera_v1  \
# 0            NaN                NaN                NaN              NaN
# 1            NaN                NaN                NaN              NaN
# 2            NaN                NaN                NaN              NaN
# 3            NaN                NaN                NaN              NaN
# 4            NaN                NaN                NaN              NaN
# 5            NaN                NaN                NaN              NaN
# 6            NaN                NaN                NaN              NaN
# 7            NaN                NaN                NaN              NaN
# 8            NaN                NaN                NaN              NaN
# 9            NaN                NaN                NaN              NaN
#
#   main_camera main_camera_quad selfie_camera_triple main_camera_v1  \
# 0         NaN              NaN                  NaN            NaN
# 1         NaN              NaN                  NaN            NaN
# 2         NaN              NaN                  NaN            NaN
# 3         NaN              NaN                  NaN            NaN
# 4         NaN              NaN                  NaN            NaN
# 5         NaN              NaN                  NaN            NaN
# 6         NaN              NaN                  NaN            NaN
# 7         NaN              NaN                  NaN            NaN
# 8         NaN              NaN                  NaN            NaN
# 9         NaN              NaN                  NaN            NaN
#
#   main_camera_dual_or_triple main_camera_five
# 0                        NaN              NaN
# 1                        NaN              NaN
# 2                        NaN              NaN
# 3                        NaN              NaN
# 4                        NaN              NaN
# 5                        NaN              NaN
# 6                        NaN              NaN
# 7                        NaN              NaN
# 8                        NaN              NaN
# 9                        NaN              NaN
#
# [10 rows x 86 columns]

# %%
param = np.array(df_2.columns)
param.T
# Out:
# array(['oem', 'model', 'network_technology', 'network_2g_bands',
#        'network_gprs', 'network_edge', 'launch_announced',
#        'launch_status', 'body_dimensions', 'body_weight', 'body_sim',
#        'body', 'display_type', 'display_size', 'display_resolution',
#        'platform_os', 'platform_chipset', 'platform_cpu',
#        'memory_card_slot', 'memory_internal', 'main_camera_single',
#        'main_camera_video', 'selfie_camera_single', 'selfie_camera_video',
#        'sound_loudspeaker', 'sound_3.5mm_jack', 'comms_wlan',
#        'comms_bluetooth', 'comms_gps', 'comms_radio', 'comms_usb',
#        'features_sensors', 'battery', 'battery_talk_time', 'misc_colors',
#        'misc_price', 'network_3g_bands', 'network_4g_bands', 'network',
#        'network_speed', 'platform_gpu', 'main_camera_features', 'sound',
#        'features', 'selfie_camera_features', 'battery_stand-by',
#        'tests_performance', 'tests_display', 'tests_camera',
#        'tests_loudspeaker', 'tests_audio_quality', 'tests_battery_life',
#        'display_protection', 'battery_charging', 'misc_models',
#        'comms_nfc', 'misc_sar_eu', 'battery_music_play', 'selfie_camera',
#        'display', 'misc_sar', 'features_browser', 'body_keyboard',
#        'main_camera_dual', 'comms_infrared_port', 'selfie_camera_dual',
#        'body_build', 'camera', 'memory_phonebook', 'memory_call_records',
#        'features_messaging', 'features_games', 'features_java', 'memory',
#        'sound_alert_types', 'features_clock', 'features_alarm',
#        'features_languages', 'main_camera_triple', 'selfie_camera_v1',
#        'main_camera', 'main_camera_quad', 'selfie_camera_triple',
#        'main_camera_v1', 'main_camera_dual_or_triple', 'main_camera_five'],
#       dtype=object)

# %%
with open('columns.csv','wb') as file:
    for line in param:
        file.write(line)
        file.write('\n')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-98139c11c0c2> in <module>
#       1 with open('columns.csv','wb') as file:
#       2     for line in param:
# ----> 3         file.write(line)
#       4         file.write('\n')
#
# TypeError: a bytes-like object is required, not 'str'

# %%
with open('columns.csv','wb') as file:
    for line in param:
        writer = csv.writer(file, dialect='excel')
        writer.writerows(param)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-7ecbb2f3180f> in <module>
#       2     for line in param:
#       3         writer = csv.writer(file, dialect='excel', delimiter = ',')
# ----> 4         writer.writerows(param)
#
# TypeError: a bytes-like object is required, not 'str'
