# %%
import numpy as np
import pandas as pd
# import matplotlib.pyplot as plt

import csv
import sys, os
sys.path.append('~/dsi/capstones/cap_3/')

# from pyspark.sql.types import StructType, StructField, IntegerType, StringType, FloatType, DateType
# import pyspark as ps

# import scipy as stats
import re
import dateparser
import datetime
import math
# import json

# import researchpy as rp
# import statsmodels.api as sm
# from statsmodels.formula.api import ols

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 500)

# %%
df_org = pd.read_csv('../results/selected_df.csv')
df = df_org.copy()
df.drop(columns='Unnamed: 0', inplace=True)

# %%
print(df['oem'].unique())
print(len(df['oem'].unique()))
# Out:
# ['Acer' 'alcatel' 'Allview' 'Amazon' 'Amoi' 'Apple' 'Archos' 'Asus' 'AT&T'
#  'Benefon' 'BenQ' 'BenQ-Siemens' 'Bird' 'BlackBerry' 'Blackview' 'BLU'
#  'BQ' 'Casio' 'Cat' 'Celkon' 'Coolpad' 'Dell' 'Emporia' 'Energizer' 'Eten'
#  'Fujitsu Siemens' 'Garmin-Asus' 'Gigabyte' 'Gionee' 'Google' 'Haier'
#  'Honor' 'HP' 'HTC' 'Huawei' 'i-mate' 'i-mobile' 'Icemobile' 'Infinix'
#  'iNQ' 'Intex' 'Jolla' 'Karbonn' 'Kyocera' 'Lava' 'LeEco' 'Lenovo' 'LG'
#  'Maxwest' 'Meizu' 'Micromax' 'Microsoft' 'Mitac' 'Modu' 'Motorola' 'MWg'
#  'NEC' 'Neonode' 'NIU' 'Nokia' 'Nvidia' 'O2' 'OnePlus' 'Oppo' 'Orange'
#  'Palm' 'Panasonic' 'Pantech' 'Parla' 'Philips' 'Plum' 'Posh' 'Prestigio'
#  'QMobile' 'Qtek' 'Razer' 'Realme' 'Sagem' 'Samsung' 'Sharp' 'Sonim'
#  'Sony' 'Sony Ericsson' 'Spice' 'T-Mobile' 'TECNO' 'Telit' 'Thuraya'
#  'Toshiba' 'Unnecto' 'Vertu' 'verykool' 'vivo' 'VK Mobile' 'Vodafone'
#  'Wiko' 'WND' 'XCute' 'Xiaomi' 'XOLO' 'Yezz' 'Yota' 'YU' 'ZTE']
# 104

# %%
df['oem'].value_counts()
# Out:
# Samsung            1016
# LG                  527
# Nokia               344
# alcatel             310
# Motorola            303
# BLU                 279
# Micromax            274
# Huawei              263
# ZTE                 246
# HTC                 244
# Celkon              229
# Lenovo              185
# Asus                173
# Philips             171
# Allview             143
# Sony Ericsson       140
# verykool            139
# Spice               119
# Sony                117
# Lava                115
# Plum                106
# Acer                 94
# Yezz                 91
# Oppo                 91
# vivo                 90
# QMobile              90
# Xiaomi               88
# Vodafone             81
# XOLO                 80
# Gionee               79
#                    ...
# Vertu                13
# YU                   13
# Palm                 12
# OnePlus              10
# Parla                10
# LeEco                 9
# VK Mobile             9
# ...

# %%
df
# Out:
#        oem                 model network_technology                                   network_2g_bands    network_gprs network_edge launch_announced         body_weight                                           body_sim    body                                       display_type                                       display_size                                 display_resolution                                        platform_os                              platform_chipset  \
# 0     Acer     Chromebook Tab 10                NaN                                                NaN             NaN          NaN          2018-03   544.3 g (1.20 lb)                                                NaN  Stylus         IPS LCD capacitive touchscreen, 16M colors  9.7 inches, 291.4 cm (~71.0% screen-to-body ra...   1536 x 2048 pixels, 4:3 ratio (~264 ppi density)                                          Chrome OS                               Rockchip RK3399
# ...

# %%
df_phone = df.loc[(df['is_tablet'] == False) & (df['is_watch'] == False)]

# %%
df_phone
# Out:
#        oem                model network_technology                                   network_2g_bands    network_gprs network_edge launch_announced         body_weight                                           body_sim body                                     display_type                                       display_size                                 display_resolution                                        platform_os                              platform_chipset  \
# 1     Acer        Iconia Talk S   GSM / HSPA / LTE        GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2             Yes          Yes          2016-08     260 g (9.17 oz)                      Dual SIM (Micro-SIM/Nano-SIM)  NaN       IPS LCD capacitive touchscreen, 16M colors  7.0 inches, 135.1 cm (~69.8% screen-to-body ra...   720 x 1280 pixels, 16:9 ratio (~210 ppi density)                          Android 6.0 (Marshmallow)                               Mediatek MT8735
# ...

# %%
print(df_phone['oem'].unique())
print(len(df_phone['oem'].unique()))
# Out:
# ['Acer' 'alcatel' 'Allview' 'Amazon' 'Amoi' 'Apple' 'Archos' 'Asus' 'AT&T'
#  'Benefon' 'BenQ' 'BenQ-Siemens' 'Bird' 'BlackBerry' 'Blackview' 'BLU'
#  'BQ' 'Casio' 'Cat' 'Celkon' 'Coolpad' 'Dell' 'Emporia' 'Energizer' 'Eten'
#  'Fujitsu Siemens' 'Garmin-Asus' 'Gigabyte' 'Gionee' 'Google' 'Haier'
#  'Honor' 'HP' 'HTC' 'Huawei' 'i-mate' 'i-mobile' 'Icemobile' 'Infinix'
#  'iNQ' 'Intex' 'Jolla' 'Karbonn' 'Kyocera' 'Lava' 'LeEco' 'Lenovo' 'LG'
#  'Maxwest' 'Meizu' 'Micromax' 'Microsoft' 'Mitac' 'Modu' 'Motorola' 'MWg'
#  'NEC' 'Neonode' 'NIU' 'Nokia' 'Nvidia' 'O2' 'OnePlus' 'Oppo' 'Orange'
#  'Palm' 'Panasonic' 'Pantech' 'Parla' 'Philips' 'Plum' 'Posh' 'Prestigio'
#  'QMobile' 'Qtek' 'Razer' 'Realme' 'Sagem' 'Samsung' 'Sharp' 'Sonim'
#  'Sony' 'Sony Ericsson' 'Spice' 'T-Mobile' 'TECNO' 'Telit' 'Thuraya'
#  'Toshiba' 'Unnecto' 'Vertu' 'verykool' 'vivo' 'VK Mobile' 'Vodafone'
#  'Wiko' 'WND' 'XCute' 'Xiaomi' 'XOLO' 'Yezz' 'Yota' 'YU' 'ZTE']
# 104

# %%
df_phone['oem'].value_counts()
# Out:
# Samsung            935
# LG                 520
# Nokia              344
# alcatel            308
# Motorola           303
# BLU                278
# Micromax           270
# Huawei             256
# HTC                244
# ZTE                241
# Celkon             229
# Philips            171
# Asus               168
# Lenovo             151
# Sony Ericsson      140
# verykool           139
# Allview            139
# Spice              119
# Lava               115
# Plum               106
# Sony               102
# Yezz                91
# Oppo                91
# vivo                90
# Xiaomi              88
# QMobile             88
# Gionee              79
# Panasonic           78
# XOLO                78
# Acer                72
#                   ...
# Vertu               13
# YU                  13
# Palm                12
# OnePlus             10
# Parla               10
# LeEco                9
# VK Mobile            9
# Modu                 8
# NEC                  8
# ...

# %%
oems_less_than_four = ['Noenode', 'Thuraya', 'Razer', 'Fujitsu Siemens', 'Benefon', 'XCute', 
                       'Jolla', 'Nvidia', 'Qtek']

# %%
df_phone_2 = df_phone[~df_phone['oem'].isin(oems_less_than_four)]

# %%
df_phone_2
# Out:
#        oem                model network_technology                                   network_2g_bands    network_gprs network_edge launch_announced         body_weight                                           body_sim body                                     display_type                                       display_size                                 display_resolution                                        platform_os                              platform_chipset  \
# 1     Acer        Iconia Talk S   GSM / HSPA / LTE        GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2             Yes          Yes          2016-08     260 g (9.17 oz)                      Dual SIM (Micro-SIM/Nano-SIM)  NaN       IPS LCD capacitive touchscreen, 16M colors  7.0 inches, 135.1 cm (~69.8% screen-to-body ra...   720 x 1280 pixels, 16:9 ratio (~210 ppi density)                          Android 6.0 (Marshmallow)                               Mediatek MT8735
# ...

# %%
print(df_phone_2['oem'].unique())
print(len(df_phone_2['oem'].unique()))
# Out:
# ['Acer' 'alcatel' 'Allview' 'Amazon' 'Amoi' 'Apple' 'Archos' 'Asus' 'AT&T'
#  'BenQ' 'BenQ-Siemens' 'Bird' 'BlackBerry' 'Blackview' 'BLU' 'BQ' 'Casio'
#  'Cat' 'Celkon' 'Coolpad' 'Dell' 'Emporia' 'Energizer' 'Eten'
#  'Garmin-Asus' 'Gigabyte' 'Gionee' 'Google' 'Haier' 'Honor' 'HP' 'HTC'
#  'Huawei' 'i-mate' 'i-mobile' 'Icemobile' 'Infinix' 'iNQ' 'Intex'
#  'Karbonn' 'Kyocera' 'Lava' 'LeEco' 'Lenovo' 'LG' 'Maxwest' 'Meizu'
#  'Micromax' 'Microsoft' 'Mitac' 'Modu' 'Motorola' 'MWg' 'NEC' 'Neonode'
#  'NIU' 'Nokia' 'O2' 'OnePlus' 'Oppo' 'Orange' 'Palm' 'Panasonic' 'Pantech'
#  'Parla' 'Philips' 'Plum' 'Posh' 'Prestigio' 'QMobile' 'Realme' 'Sagem'
#  'Samsung' 'Sharp' 'Sonim' 'Sony' 'Sony Ericsson' 'Spice' 'T-Mobile'
#  'TECNO' 'Telit' 'Toshiba' 'Unnecto' 'Vertu' 'verykool' 'vivo' 'VK Mobile'
#  'Vodafone' 'Wiko' 'WND' 'Xiaomi' 'XOLO' 'Yezz' 'Yota' 'YU' 'ZTE']
# 96

# %%
test = np.array([1,2,3,7,5])

# %%
test.max()
# Out:
# 7

# %%
test[test<max(test)]
# Out:
# array([1, 2, 3, 5])

# %%
test = test[test<max(test)]

# %%
test
# Out:
# array([1, 2, 3, 5])
